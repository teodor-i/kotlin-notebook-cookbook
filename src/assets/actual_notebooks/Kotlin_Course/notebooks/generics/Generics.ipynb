// %% [markdown]
// <img alt="Cover" src="./images/1.cover.png" width="3000" />
//
// ---

// %% [markdown]
// # What? Why?

// %%
fun quickSort(collection: List<Int>) {  }

// %%
quickSort(listOf(1, 2, 3)) // OK

// %%
quickSort(listOf(1.0, 2.0, 3.0)) // NOT OK
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[3], line 1, column 11: Type mismatch: inferred type is List<Double> but List<Int> was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %%
fun quickSort(collection: List<Double>) {  } // overload (we’ll get back to this a bit later)

// %%
quickSort(listOf(1.0, 2.0, 3.0)) // OK

// %%
quickSort(listOf(1, 2, 3)) // OK

// %% [markdown]
// <font size="5">Kotlin `Number` inheritors: `Int`, `Double`, `Byte`, `Float`, `Long`, `Short`. Do we need 4 more implementations of quickSort?</font>
//
// ---

// %% [markdown]
// # How?
//
// <font size="5">Does the quickSort algorithm actually care what is it sorting? No, as long as it can compare two values against each other.</font>

// %%
fun <T : Comparable<T>> quickSort(collection: Collection<T>): Collection<T> = collection // We will not implement it

// %%
quickSort(listOf(1.0, 2.0, 3.0)) // OK
// Out:
// [1.0, 2.0, 3.0]

// %%
quickSort(listOf(1, 2, 3)) // OK
// Out:
// [1, 2, 3]

// %%
quickSort(listOf("one", "two", "three")) // OK
// Out:
// [one, two, three]

// %% [markdown]
// <font size="5">Generics allow you to write code that can work with any type or with types that should satisfy some rules (constraints) but are not limited in any other ways: type parameters.</font>

// %%
data class Holder<T>(val value: T)

// %%
val intHolder = Holder<Int>(23)
println(intHolder)
// Out:
// Holder(value=23)

// %%
val cupHolder = Holder("cup") // Generic parameter type can be inferred
println(cupHolder)
// Out:
// Holder(value=cup)

// %% [markdown]
// ---
//
// # Constraints
//
// <font size="5">Sometimes we do not want to work with an arbitrary type and expect it to provide us with some functionality. In such cases type constraints in the form of upper bounds are used: upper bounds.</font>

// %%
import org.jetbrains.kotlin.public.course.generics.Movable

class Pilot<T : Movable>(val vehicle: T) {
    fun go() { vehicle.move() }
}

// %%
import org.jetbrains.kotlin.public.course.generics.Car

val ryanGosling = Pilot<Car>(Car("Chevy", "Malibu"))
ryanGosling.go()
// Out:
// Car is moving

// %%
import org.jetbrains.kotlin.public.course.generics.Plane

val sullySullenberger = Pilot<Plane>(Plane("Airbus", "A320"))
sullySullenberger.go()
// Out:
// Plane is moving

// %% [markdown]
// ---
//
// # Constraints continued
//
// <font size="5">There can be several parameter types, and generic classes can participate in inheritance.</font>

// %%
public interface MutableMap<K, V> : Map<K, V> {  }

// %% [markdown]
// <font size="5">There can also be several constraints (which means the type parameter has to implement several interfaces):</font>

// %%
import org.jetbrains.kotlin.public.course.generics.Awesome

fun <T, S> moveInAnAwesomeWayAndCompare(a: T, b: S) where T : Comparable<T>, S : Comparable<T>, T : Awesome, T : Movable {  }

// %% [markdown]
// ---
//
// # Star-projection
//
// <font size="5">When you do not care about the parameter type, you can use star-projection `*`.</font>

// %%
fun printKeys(map: MutableMap<*, *>) {  }

// %% [markdown]
// ---
//
// # Let's go back

// %%
open class A
open class B : A()
class C : B()

// Nothing <: C <: B <: A <: Any

// %% [markdown]
// <font size="5">This means that the `Any` class is the _superclass_ for all the classes and at the same time `Nothing` is a _subtype_ of any type</font>
//
// <font size="5">Consider a basic example:</font>

// %%
interface HolderExample<T> {
    fun push(newValue: T) // consumes an element
    
    fun pop(): T // produces an element
    
    fun size(): Int // does not interact with T
}

// %% [markdown]
// <font size="5">In Kotlin there are type projections:</font>
//
// <font size="5">`G<T>` // invariant, can **consume** and **produce** elements </font>
// <font size="5">`G<in T>` // contravariant, can only **consume** elements </font>
// <font size="5">`G<out T>` // covariant, can only **produce** elements </font>
// <font size="5">`G<*>` // star-projection, does not interact with T</font>

// %% [markdown]
// ---
//
// # Several examples
//
// <font size="5">`G<T>` // invariant, can **consume** and **produce** elements </font>

// %%
interface HolderSimple<T> {
     fun push(newValue: T)// consumes an element: OK
     
     fun pop(): T // produces an element: OK
     
     fun size(): Int // does not interact with T: OK
}

// %% [markdown]
// <font size="5">`G<in T>` // contravariant, can only **consume** elements </font>

// %%
interface HolderConsumer<in T> {
     fun push(newValue: T) // consumes an element: OK
     
     fun pop(): T // produces an element: ERROR: [TYPE_VARIANCE_CONFLICT_ERROR] Type parameter T is declared as 'in' but occurs in 'out' position in type T
    
     fun size(): Int // does not interact with T: OK
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[25], line 4, column 17: Type parameter T is declared as 'in' but occurs in 'out' position in type T
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">`G<out T>` // covariant, can only **produce** elements </font>

// %%
interface HolderProducer<out T> {
     fun push(newValue: T) // consumes an element: ERROR: [TYPE_VARIANCE_CONFLICT_ERROR] Type parameter T is declared as 'out' but occurs in 'in' position in type T
     fun pop(): T // produces an element: OK
     fun size(): Int // does not interact with T: OK
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[26], line 2, column 25: Type parameter T is declared as 'out' but occurs in 'in' position in type T
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">`G<*>` // star-projection, does not interact with T</font>

// %%
fun <T> foo1(holder: HolderSimple<T>, t: T) {
     holder.push(t) // OK
}

// %%
fun foo2(holder: HolderSimple<Any>, t: Any) {
    holder.push(t) // OK
}

// %%
fun <T> foo3(holder: HolderSimple<*>, t: T) {
     holder.push(t) // ERROR: [TYPE_MISMATCH] Type mismatch. Required: Nothing. Found: T
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[29], line 2, column 18: Type mismatch: inferred type is T but Nothing was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// ---
//
// # Subtyping
//
// <img alt="Cover" src="./images/2.png" width="3000" />
//
// ---

// %% [markdown]
// <img alt="Cover" src="./images/3.png" width="3000" />

// %%
val c: C = C()
val b: B = c // C <: B, OK

// %%
val holderC: Holder<C> = Holder(C())
val holderB: Holder<B> = holderC // ERROR: Type mismatch. Required: Holder<B>. Found: Holder<C>.
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[31], line 2, column 26: Type mismatch: inferred type is Line_18_jupyter.Holder<Line_27_jupyter.C> but Line_18_jupyter.Holder<Line_27_jupyter.B> was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %%
// BUT
val holderB: Holder<B> = Holder(C()) // OK, because of casting

// %% [markdown]
// ---
//
// # Subtyping: Next

// %%
class HolderSubtypingDemo<T> (var value: T?) {
   fun pop(): T? = value.also { value = null }
   fun push(newValue: T?): T? = value.also { value = newValue }
   fun steal(other: HolderSubtypingDemo<T>) { value = other.pop() }
   fun gift(other: HolderSubtypingDemo<T>) { other.push(pop()) }
}

// %% [markdown]
// <font size="5">HolderSubtypingDemo<Nothing> !<:> HolderSubtypingDemo<C> !<:> HolderSubtypingDemo<B> !<:> HolderSubtypingDemo<A> !<:> HolderSubtypingDemo<Any></font>

// %%
val holderB: HolderSubtypingDemo<B> = HolderSubtypingDemo(B())
val holderA: HolderSubtypingDemo<A> = HolderSubtypingDemo(null)
holderA.steal(holderB) // ERROR: Type mismatch. Required: Holder<A>. Found: Holder<B>.
holderB.gift(holderA) // ERROR: Type mismatch. Required: Holder<B>. Found: Holder<A>.
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[34], line 3, column 15: Type mismatch: inferred type is Line_38_jupyter.HolderSubtypingDemo<Line_27_jupyter.B> but Line_38_jupyter.HolderSubtypingDemo<Line_27_jupyter.A> was expected
// at Cell In[34], line 4, column 14: Type mismatch: inferred type is Line_38_jupyter.HolderSubtypingDemo<Line_27_jupyter.A> but Line_38_jupyter.HolderSubtypingDemo<Line_27_jupyter.B> was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// ---
//
// # Type projection: in

// %%
class HolderIn<T> (var value: T?) {
   fun pop(): T? = value.also { value = null }
   fun push(newValue: T?): T? = value.also { value = newValue }
    
   fun gift(other: HolderIn<in T>) { other.push(pop()) }
}

// %%
val holderB: HolderIn<B> = HolderIn(B())
val holderA: HolderIn<A> = HolderIn(null)
holderB.gift(holderA) // OK

// %% [markdown]
// <font size="5">Type projection: `other` is a restricted (projected) generic. You can only call methods that **accept** the type parameter `T`, which in
// this case means that you can only call `push()`.</font>
//
// <font size="5">This is contravariance:</font>
//
// <font size="5">`Nothing <: C <: B <: A <: Any`</font>
// <font size="5">`HolderIn<Nothing> :> HolderIn<C> :> HolderIn<B> :> HolderIn<A> :> HolderIn<Any>`</font>

// %% [markdown]
// ---
//
// # Type projection: out

// %%
class HolderOut<T> (var value: T?) {
   fun pop(): T? = value.also { value = null }
   fun push(newValue: T?): T? = value.also { value = newValue }

   fun steal(other: HolderOut<out T>) { value = other.pop() }
}

// %%
val holderB: HolderOut<B> = HolderOut(B())
val holderA: HolderOut<A> = HolderOut(null)
holderA.steal(holderB) // OK

// %% [markdown]
// <font size="5">Type projection: `other` is a restricted (projected) generic. You can only call methods that **return** the type parameter `T`, which in
// this case means that you can only call `pop()`.</font>
//
// <font size="5">This is covariance:</font>
//
// <font size="5">`Nothing <: C <: B <: A <: Any`</font>
// <font size="5">`HolderIn<Nothing> <: HolderIn<C> <: HolderIn<B> <: HolderIn<A> <: HolderIn<Any>`</font>

// %% [markdown]
// ---
//
// # Type projections

// %%
class HolderFinalDemo<T> (var value: T?) {
   fun pop(): T? = value.also { value = null }
   fun push(newValue: T?): T? = value.also { value = newValue }
    
    
   fun steal(other: HolderFinalDemo<out T>) {
      val oldValue = push(other.pop())
      other.push(oldValue) // ERROR: Type mismatch. Required: Nothing?. Found: T?.
   }
   fun gift(other: HolderFinalDemo<in T>) {
      val otherValue = other.push(pop())
      push(otherValue) // ERROR: Type mismatch. Required: T?. Found: Any?.
   }
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[39], line 8, column 18: Type mismatch: inferred type is T? but Nothing? was expected
// at Cell In[39], line 12, column 12: Type mismatch: inferred type is Any? but T? was expected
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">`out T` returns something that can be cast to `T` and accepts literally `Nothing`.</font>
//
// <font size="5">`in T` accepts something that can be cast to `T` and returns a meaningless `Any?`.</font>

// %% [markdown]
// ---
//
// # Type erasure
//
// <font size="5">At runtime, the instances of generic types do not hold any information about their actual type arguments. The type information is said to be erased. The same byte-code is used in all usages of the generic as opposed to C++, where each template is compiled separately for each type parameter provided.</font>
//
// <font size="5">- Any `MutableMap<K, V>` becomes `MutableMap<*, *>` in the runtime. (Actually, in the **Kotlin/JVM** runtime we have just `java.util.Map` to preserve compatibility with Java.)</font>
// <font size="5">- Any `Pilot<T : Movable>` becomes `Pilot<Movable>`.</font>

// %% [markdown]
// <font size="5">As a corollary, you cannot override a function (in **Kotlin/JVM**) by changing generic type parameters:</font>

// %%
fun quickSort(collection: Collection<Int>) {  }
fun quickSort(collection: Collection<Double>) {  }
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[41], line 1, column 15: Parameter 'collection' is never used
// at Cell In[41], line 2, column 15: Parameter 'collection' is never used
//  (1:1 - 48) Platform declaration clash: The following declarations have the same JVM signature (quickSort(Ljava/util/Collection;)V):
//     fun quickSort(collection: Collection<Double>): Unit defined in Line_46_jupyter
//     fun quickSort(collection: Collection<Int>): Unit defined in Line_46_jupyter
//  (2:1 - 51) Platform declaration clash: The following declarations have the same JVM signature (quickSort(Ljava/util/Collection;)V):
//     fun quickSort(collection: Collection<Double>): Unit defined in Line_46_jupyter
//     fun quickSort(collection: Collection<Int>): Unit defined in Line_46_jupyter
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">Both become `quickSort(collection: Collection<*>)` and their signatures clash.</font>
//
// <font size="5">But you can use the `JvmName` annotation:</font>

// %%
@JvmName("quickSortInt")
fun quickSort(collection: Collection<Int>) {  } 
fun quickSort(collection: Collection<Double>) {  }

// %% [markdown]
// ---
//
// # Nullability in generics
//
// <font size="5">Contrary to common sense, in Kotlin a type parameter specified as `T` can be nullable.</font>

// %%
class HolderNullability<T>(val value: T) {  } // Notice there is no `?`
val holderA: HolderNullability<A?> = HolderNullability(null) // T = A? and that is OK

// %% [markdown]
// <font size="5">To prohibit such behavior, you can use a non-nullable `Any` as a constraint.</font>

// %%
class HolderNotNull<T : Any>(val value: T) {  }
val holderA: HolderNotNull<A?> = HolderNotNull(null) // ERROR: Type argument is not within its bounds. Expected: Any. Found: A?.
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[44], line 2, column 28: Type argument is not within its bounds: should be subtype of 'Any'
// at Cell In[44], line 2, column 34: Type mismatch: inferred type is Line_27_jupyter.A? but Any was expected
// at Cell In[44], line 2, column 48: Null can not be a value of a non-null type TypeVariable(T)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">You may also find intersection helpful:</font>

// %%
fun <T> elvisLike(x: T, y: T & Any): T & Any = x ?: y // T & Any is populated with all values from T besides null

// %% [markdown]
// ---
//
// # Inline functions

// %% [markdown]
// <font size="5">If they are used as first-class objects, functions are stored as objects, thus requiring memory allocations, which introduce runtime overhead.</font>

// %%
fun foo(str: String, call: (String) -> Unit) {
     call(str)
}

// %%
foo("Top level function with lambda example") { print(it) }
// Out:
// Top level function with lambda example

// %% [markdown]
// <img alt="Cover" src="./images/4.png" width="3000" />

// %% [markdown]
// <img alt="Cover" src="./images/5.png" width="3000" />

// %% [markdown]
// <img alt="Cover" src="./images/6.png" width="3000" />

// %% [markdown]
// <font size="5">`inline` affects not only the function itself, but also all the lambdas passed as arguments.
// If you do not want some of the lambdas passed to an `inline` function to be inlined (_for example, inlining large functions is not recommended_), you can mark some of the function parameters with the `noinline` modifier.</font>

// %%
inline fun fooNoInlineArg(str: String, call1: (String) -> Unit, noinline call2: (String) -> Unit) { 
    call1(str) // Will be inlined
    call2(str) // Will not be inlined
}

// %% [markdown]
// <font size="5">You can use `return` in inlined lambdas, this is called _non-local return_, which can lead to unexpected behaviour:</font>

// %%
inline fun fooNonLocalReturn(call1: () -> Unit, call2: () -> Unit) {
    call1()
    call2() 
}

// %%
fun main() {
    println("Step#1")
    fooNonLocalReturn({
        println("Step#2")
        return
    }, { println("Step#3") })
    println("Step#4")
}

main()
// Out:
// Step#1
// Step#2

// %% [markdown]
// <font size="5">To prohibit returning from the lambda expression we can mark the lambda as `crossinline`:</font>

// %%
inline fun crossInlineFoo(crossinline call1: () -> Unit, call2: () -> Unit) {
    call1()
    call2() 
}

// %%
println("Step#1")
crossInlineFoo({
    println("Step#2")
     return
}, // ERROR: 'return' is not allowed here
    { println("Step#3") })
println("Step#4")
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[52], line 4, column 6: 'return' is not allowed here
// at Cell In[52], line 4, column 6: This function must return a value of type Line_57_jupyter
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %%
// BUT it works
println("Step#1")
crossInlineFoo({
    println("Step#2")
     return@crossInlineFoo
}, { println("Step#3") })
println("Step#4")
// Out:
// Step#1
// Step#2
// Step#3
// Step#4

// %% [markdown]
// <font size="5">`crossinline` is especially useful when the lambda from an `inline` function is being called from another context, for example, if it is used to instantiate a `Runnable`:</font>

// %%
import kotlin.concurrent.thread

inline fun drive(crossinline specialCall: (String) -> Unit, call: (String) -> Unit) { 
    val nightCall = Runnable { specialCall("There's something inside you") }
    call("I'm giving you a nightcall to tell you how I feel")
    thread { nightCall.run() }
    call("I'm gonna drive you through the night, down the hills")
}

// %%
// Switch to Crossinline2.kt (an Notebook bug)

drive({ System.err.println(it) }) { println(it) }
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: Backend Internal error: Exception during IR lowering
// File being compiled: Line_60.jupyter.kts
// The root cause java.lang.RuntimeException was thrown at: org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:51)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)
// Caused by: org.jetbrains.kotlin.backend.common.BackendException: Backend Internal error: Exception during IR lowering
// File being compiled: Line_60.jupyter.kts
// The root cause java.lang.RuntimeException was thrown at: org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:51)
// 	at org.jetbrains.kotlin.backend.common.CodegenUtil.reportBackendException(CodegenUtil.kt:253)
// 	at org.jetbrains.kotlin.backend.common.CodegenUtil.reportBackendException$default(CodegenUtil.kt:237)
// 	at org.jetbrains.kotlin.backend.common.phaser.PerformByIrFilePhase.invokeSequential(performByIrFile.kt:65)
// 	at org.jetbrains.kotlin.backend.common.phaser.PerformByIrFilePhase.invoke(performByIrFile.kt:52)
// 	at org.jetbrains.kotlin.backend.common.phaser.PerformByIrFilePhase.invoke(performByIrFile.kt:38)
// 	at org.jetbrains.kotlin.backend.common.phaser.NamedCompilerPhase.phaseBody(CompilerPhase.kt:147)
// 	at org.jetbrains.kotlin.backend.common.phaser.AbstractNamedCompilerPhase.invoke(CompilerPhase.kt:94)
// 	at org.jetbrains.kotlin.backend.common.phaser.CompositePhase.invoke(PhaseBuilders.kt:29)
// 	at org.jetbrains.kotlin.backend.common.phaser.CompositePhase.invoke(PhaseBuilders.kt:16)
// 	at org.jetbrains.kotlin.backend.common.phaser.NamedCompilerPhase.phaseBody(CompilerPhase.kt:147)
// 	at org.jetbrains.kotlin.backend.common.phaser.AbstractNamedCompilerPhase.invoke(CompilerPhase.kt:94)
// 	at org.jetbrains.kotlin.backend.common.phaser.CompilerPhaseKt.invokeToplevel(CompilerPhase.kt:43)
// 	at org.jetbrains.kotlin.backend.jvm.JvmIrCodegenFactory.invokeCodegen(JvmIrCodegenFactory.kt:361)
// 	at org.jetbrains.kotlin.codegen.CodegenFactory.generateModule(CodegenFactory.kt:45)
// 	at org.jetbrains.kotlin.scripting.compiler.plugin.impl.KJvmReplCompilerBase.generateWithBackendIr(KJvmReplCompilerBase.kt:216)
// 	at org.jetbrains.kotlin.scripting.compiler.plugin.impl.KJvmReplCompilerBase.compile$suspendImpl(KJvmReplCompilerBase.kt:150)
// 	at org.jetbrains.kotlin.scripting.compiler.plugin.impl.KJvmReplCompilerBase.compile(KJvmReplCompilerBase.kt)
// 	at kotlin.script.experimental.api.ReplCompiler.compile$suspendImpl(replCompilation.kt:49)
// 	at kotlin.script.experimental.api.ReplCompiler.compile(replCompilation.kt)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl$compileSync$resultWithDiagnostics$1.invokeSuspend(JupyterCompilerImpl.kt:201)
// 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
// 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
// 	at kotlinx.coroutines.EventLoopImplBase.processNextEvent(EventLoop.common.kt:277)
// 	at kotlinx.coroutines.BlockingCoroutine.joinBlocking(Builders.kt:95)
// 	at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking(Builders.kt:69)
// 	at kotlinx.coroutines.BuildersKt.runBlocking(Unknown Source)
// 	at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking$default(Builders.kt:48)
// 	at kotlinx.coroutines.BuildersKt.runBlocking$default(Unknown Source)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:201)
// 	... 35 more
// Caused by: java.lang.RuntimeException: Exception while generating code for:
// CONSTRUCTOR visibility:public <> ($this:<root>.Line_60_jupyter, <earlierScripts>:kotlin.Array<kotlin.Any>, userHandlesProvider:jupyter.kotlin.providers.UserHandlesProvider) returnType:<root>.Line_60_jupyter [primary]
//   $outer: VALUE_PARAMETER SCRIPT_THIS_RECEIVER name:<this> type:<root>.Line_60_jupyter
//   VALUE_PARAMETER SCRIPT_CALL_PARAMETER name:<earlierScripts> index:0 type:kotlin.Array<kotlin.Any>
//   VALUE_PARAMETER SCRIPT_CALL_PARAMETER name:userHandlesProvider index:1 type:jupyter.kotlin.providers.UserHandlesProvider
//   BLOCK_BODY
//     DELEGATING_CONSTRUCTOR_CALL 'public constructor <init> (userHandlesProvider: jupyter.kotlin.providers.UserHandlesProvider) [primary] declared in jupyter.kotlin.ScriptTemplateWithDisplayHelpers'
//       userHandlesProvider: GET_VAR 'userHandlesProvider: jupyter.kotlin.providers.UserHandlesProvider declared in <root>.Line_60_jupyter.<init>' type=jupyter.kotlin.providers.UserHandlesProvider origin=null
//     SET_FIELD 'FIELD SCRIPT_EARLIER_SCRIPTS name:$$earlierScripts type:kotlin.Array<kotlin.Any> visibility:private [final]' type=kotlin.Unit origin=null
//       receiver: GET_VAR '<this>: <root>.Line_60_jupyter declared in <root>.Line_60_jupyter' type=<root>.Line_60_jupyter origin=null
//       value: GET_VAR '<earlierScripts>: kotlin.Array<kotlin.Any> declared in <root>.Line_60_jupyter.<init>' type=kotlin.Array<kotlin.Any> origin=null
//     SET_FIELD 'FIELD SCRIPT_CALL_PARAMETER name:userHandlesProvider type:jupyter.kotlin.providers.UserHandlesProvider visibility:local [final]' type=kotlin.Unit origin=null
//       receiver: GET_VAR '<this>: <root>.Line_60_jupyter declared in <root>.Line_60_jupyter' type=<root>.Line_60_jupyter origin=null
//       value: GET_VAR 'userHandlesProvider: jupyter.kotlin.providers.UserHandlesProvider declared in <root>.Line_60_jupyter.<init>' type=jupyter.kotlin.providers.UserHandlesProvider origin=null
//     BLOCK type=kotlin.Unit origin=null
//       BLOCK type=kotlin.Unit origin=SYNTHESIZED_INIT_BLOCK
//         CALL 'public final fun drive (specialCall: kotlin.Function1<kotlin.String, kotlin.Unit>, call: kotlin.Function1<kotlin.String, kotlin.Unit>): kotlin.Unit [inline] declared in <root>.Line_59_jupyter' type=kotlin.Unit origin=null
//           $this: TYPE_OP type=<root>.Line_59_jupyter origin=IMPLICIT_CAST typeOperand=<root>.Line_59_jupyter
//             TYPE_OP type=<root>.Line_59_jupyter origin=IMPLICIT_CAST typeOperand=<root>.Line_59_jupyter
//               CALL 'public final fun get (index: kotlin.Int): T of kotlin.Array [operator] declared in kotlin.Array' type=T of kotlin.Array origin=null
//                 $this: GET_VAR '<earlierScripts>: kotlin.Array<kotlin.Any> declared in <root>.Line_60_jupyter.<init>' type=kotlin.Array<T of kotlin.Array> origin=null
//                 index: CONST Int type=kotlin.Int value=48
//           specialCall: BLOCK type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=LAMBDA
//             COMPOSITE type=kotlin.Unit origin=null
//             FUNCTION_REFERENCE 'private final fun _init_$lambda$0 (it: kotlin.String): kotlin.Unit declared in <root>.Line_60_jupyter' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=INLINE_LAMBDA reflectionTarget=null
//           call: BLOCK type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=LAMBDA
//             COMPOSITE type=kotlin.Unit origin=null
//             FUNCTION_REFERENCE 'private final fun _init_$lambda$1 (it: kotlin.String): kotlin.Unit declared in <root>.Line_60_jupyter' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=INLINE_LAMBDA reflectionTarget=null
//
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:51)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate$default(FunctionCodegen.kt:43)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.generateMethodNode(ClassCodegen.kt:390)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.generateMethod(ClassCodegen.kt:407)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.generate(ClassCodegen.kt:169)
// 	at org.jetbrains.kotlin.backend.jvm.FileCodegen.lower(JvmPhases.kt:41)
// 	at org.jetbrains.kotlin.backend.common.phaser.FileLoweringPhaseAdapter.invoke(PhaseBuilders.kt:120)
// 	at org.jetbrains.kotlin.backend.common.phaser.FileLoweringPhaseAdapter.invoke(PhaseBuilders.kt:116)
// 	at org.jetbrains.kotlin.backend.common.phaser.NamedCompilerPhase.phaseBody(CompilerPhase.kt:147)
// 	at org.jetbrains.kotlin.backend.common.phaser.AbstractNamedCompilerPhase.invoke(CompilerPhase.kt:94)
// 	at org.jetbrains.kotlin.backend.common.phaser.PerformByIrFilePhase.invokeSequential(performByIrFile.kt:62)
// 	... 61 more
// Caused by: org.jetbrains.kotlin.codegen.CompilationException: Back-end (JVM) Internal error: Couldn't inline method call: CALL 'public final fun drive (specialCall: kotlin.Function1<kotlin.String, kotlin.Unit>, call: kotlin.Function1<kotlin.String, kotlin.Unit>): kotlin.Unit [inline] declared in <root>.Line_59_jupyter' type=kotlin.Unit origin=null
// Method: null
// File is unknown
// The root cause java.lang.RuntimeException was thrown at: org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:51)
// 	at org.jetbrains.kotlin.codegen.inline.InlineCodegen.performInline(InlineCodegen.kt:67)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.IrInlineCodegen.genInlineCall(IrInlineCodegen.kt:162)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.IrInlineCallGenerator.genCall(IrInlineCallGenerator.kt:36)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitCall(ExpressionCodegen.kt:627)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitCall(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrCall.accept(IrCall.kt:26)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitStatementContainer(ExpressionCodegen.kt:562)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:576)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.visitors.IrElementVisitor$DefaultImpls.visitBlock(IrElementVisitor.kt:192)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:396)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrBlock.accept(IrBlock.kt:20)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitStatementContainer(ExpressionCodegen.kt:562)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:576)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.visitors.IrElementVisitor$DefaultImpls.visitBlock(IrElementVisitor.kt:192)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:396)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrBlock.accept(IrBlock.kt:20)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitStatementContainer(ExpressionCodegen.kt:562)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlockBody(ExpressionCodegen.kt:567)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlockBody(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrBlockBody.accept(IrBlockBody.kt:25)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.generate(ExpressionCodegen.kt:228)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.doGenerate(FunctionCodegen.kt:122)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:47)
// 	... 71 more
// Caused by: java.lang.RuntimeException: Exception while generating code for:
// FUN name:drive visibility:public modality:FINAL <> ($this:<root>.Line_59_jupyter, specialCall:kotlin.Function1<kotlin.String, kotlin.Unit>, call:kotlin.Function1<kotlin.String, kotlin.Unit>) returnType:kotlin.Unit [inline]
//   $this: VALUE_PARAMETER name:<this> type:<root>.Line_59_jupyter
//   VALUE_PARAMETER name:specialCall index:0 type:kotlin.Function1<kotlin.String, kotlin.Unit> [crossinline]
//   VALUE_PARAMETER name:call index:1 type:kotlin.Function1<kotlin.String, kotlin.Unit>
//   BLOCK_BODY
//     VAR name:$i$f$drive type:kotlin.Int [val]
//       CONST Int type=kotlin.Int value=0
//     VAR name:nightCall type:java.lang.Runnable [val]
//       BLOCK type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//         CLASS LAMBDA_IMPL CLASS name:<no name provided> modality:FINAL visibility:public superTypes:[@[RawType] java.lang.Runnable]
//           $this: VALUE_PARAMETER INSTANCE_RECEIVER name:<this> type:<root>.Line_59_jupyter.drive.<no name provided>
//           CONSTRUCTOR GENERATED_MEMBER_IN_CALLABLE_REFERENCE visibility:public <> ($specialCall:kotlin.Function1<kotlin.String, kotlin.Unit>) returnType:<root>.Line_59_jupyter.drive.<no name provided> [primary]
//             VALUE_PARAMETER BOUND_VALUE_PARAMETER name:$specialCall index:0 type:kotlin.Function1<kotlin.String, kotlin.Unit> [crossinline]
//             BLOCK_BODY
//               SET_FIELD 'FIELD FIELD_FOR_CROSSINLINE_CAPTURED_VALUE name:$specialCall type:kotlin.Function1<kotlin.String, kotlin.Unit> visibility:public/*package*/ [final]' type=kotlin.Unit origin=INITIALIZER_OF_FIELD_FOR_CAPTURED_VALUE
//                 receiver: GET_VAR '<this>: <root>.Line_59_jupyter.drive.<no name provided> declared in <root>.Line_59_jupyter.drive.<no name provided>' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//                 value: GET_VAR '$specialCall: kotlin.Function1<kotlin.String, kotlin.Unit> [crossinline] declared in <root>.Line_59_jupyter.drive.<no name provided>.<init>' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=null
//               DELEGATING_CONSTRUCTOR_CALL 'public constructor <init> () [primary] declared in kotlin.Any'
//               BLOCK type=kotlin.Unit origin=null
//           FUN name:run visibility:public modality:FINAL <> ($this:<root>.Line_59_jupyter.drive.<no name provided>) returnType:kotlin.Unit
//             overridden:
//               public abstract fun run (): kotlin.Unit declared in java.lang.Runnable
//             $this: VALUE_PARAMETER INSTANCE_RECEIVER name:<this> type:<root>.Line_59_jupyter.drive.<no name provided>
//             BLOCK_BODY
//               CALL 'public abstract fun invoke (p1: P1 of kotlin.Function1): R of kotlin.Function1 [operator] declared in kotlin.Function1' type=kotlin.Unit origin=INVOKE
//                 $this: GET_FIELD 'FIELD FIELD_FOR_CROSSINLINE_CAPTURED_VALUE name:$specialCall type:kotlin.Function1<kotlin.String, kotlin.Unit> visibility:public/*package*/ [final]' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=null
//                   receiver: GET_VAR '<this>: <root>.Line_59_jupyter.drive.<no name provided> declared in <root>.Line_59_jupyter.drive.<no name provided>.run' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//                 p1: CONST String type=kotlin.String value="There's something inside you"
//           FIELD FIELD_FOR_CROSSINLINE_CAPTURED_VALUE name:$specialCall type:kotlin.Function1<kotlin.String, kotlin.Unit> visibility:public/*package*/ [final]
//         CONSTRUCTOR_CALL 'public constructor <init> ($specialCall: kotlin.Function1<kotlin.String, kotlin.Unit>) [primary] declared in <root>.Line_59_jupyter.drive.<no name provided>' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//           $specialCall: GET_VAR 'specialCall: kotlin.Function1<kotlin.String, kotlin.Unit> [crossinline] declared in <root>.Line_59_jupyter.drive' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=null
//     CALL 'public abstract fun invoke (p1: P1 of kotlin.Function1): R of kotlin.Function1 [operator] declared in kotlin.Function1' type=kotlin.Unit origin=INVOKE
//       $this: GET_VAR 'call: kotlin.Function1<kotlin.String, kotlin.Unit> declared in <root>.Line_59_jupyter.drive' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=VARIABLE_AS_FUNCTION
//       p1: CONST String type=kotlin.String value="I'm giving you a nightcall to tell you how I feel"
//     COMPOSITE type=kotlin.Unit origin=null
//       CALL 'public final fun thread$default (start: kotlin.Boolean, isDaemon: kotlin.Boolean, contextClassLoader: java.lang.ClassLoader?, name: kotlin.String?, priority: kotlin.Int, block: kotlin.Function0<kotlin.Unit>, $mask0: kotlin.Int, $handler: kotlin.Any?): java.lang.Thread declared in kotlin.concurrent.ThreadsKt' type=java.lang.Thread origin=DEFAULT_DISPATCH_CALL
//         start: COMPOSITE type=kotlin.Boolean origin=DEFAULT_VALUE
//           CONST Boolean type=kotlin.Boolean value=false
//         isDaemon: COMPOSITE type=kotlin.Boolean origin=DEFAULT_VALUE
//           CONST Boolean type=kotlin.Boolean value=false
//         contextClassLoader: COMPOSITE type=java.lang.ClassLoader? origin=DEFAULT_VALUE
//           CONST Null type=java.lang.ClassLoader? value=null
//         name: COMPOSITE type=kotlin.String? origin=DEFAULT_VALUE
//           CONST Null type=kotlin.String? value=null
//         priority: COMPOSITE type=kotlin.Int origin=DEFAULT_VALUE
//           CONST Int type=kotlin.Int value=0
//         block: BLOCK type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//           CLASS LAMBDA_IMPL CLASS name:<no name provided> modality:FINAL visibility:public superTypes:[kotlin.jvm.internal.Lambda; kotlin.Function0<kotlin.Unit>]
//             $this: VALUE_PARAMETER INSTANCE_RECEIVER name:<this> type:<root>.Line_59_jupyter.drive.<no name provided>
//             CONSTRUCTOR GENERATED_MEMBER_IN_CALLABLE_REFERENCE visibility:public <> ($nightCall:java.lang.Runnable) returnType:<root>.Line_59_jupyter.drive.<no name provided> [primary]
//               VALUE_PARAMETER BOUND_VALUE_PARAMETER name:$nightCall index:0 type:java.lang.Runnable
//               BLOCK_BODY
//                 SET_FIELD 'FIELD FIELD_FOR_CAPTURED_VALUE name:$nightCall type:java.lang.Runnable visibility:public/*package*/ [final]' type=kotlin.Unit origin=INITIALIZER_OF_FIELD_FOR_CAPTURED_VALUE
//                   receiver: GET_VAR '<this>: <root>.Line_59_jupyter.drive.<no name provided> declared in <root>.Line_59_jupyter.drive.<no name provided>' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//                   value: GET_VAR '$nightCall: java.lang.Runnable declared in <root>.Line_59_jupyter.drive.<no name provided>.<init>' type=java.lang.Runnable origin=null
//                 DELEGATING_CONSTRUCTOR_CALL 'public constructor <init> (arity: kotlin.Int) declared in kotlin.jvm.internal.Lambda'
//                   arity: CONST Int type=kotlin.Int value=0
//                 BLOCK type=kotlin.Unit origin=null
//             FUN name:invoke visibility:public modality:FINAL <> ($this:<root>.Line_59_jupyter.drive.<no name provided>) returnType:kotlin.Unit
//               overridden:
//                 public abstract fun invoke (): R of kotlin.Function0 [operator] declared in kotlin.Function0
//               $this: VALUE_PARAMETER INSTANCE_RECEIVER name:<this> type:<root>.Line_59_jupyter.drive.<no name provided>
//               BLOCK_BODY
//                 CALL 'public abstract fun run (): kotlin.Unit declared in java.lang.Runnable' type=kotlin.Unit origin=null
//                   $this: GET_FIELD 'FIELD FIELD_FOR_CAPTURED_VALUE name:$nightCall type:java.lang.Runnable visibility:public/*package*/ [final]' type=java.lang.Runnable origin=null
//                     receiver: GET_VAR '<this>: <root>.Line_59_jupyter.drive.<no name provided> declared in <root>.Line_59_jupyter.drive.<no name provided>.invoke' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//             FIELD FIELD_FOR_CAPTURED_VALUE name:$nightCall type:java.lang.Runnable visibility:public/*package*/ [final]
//             FUN BRIDGE name:invoke visibility:public modality:OPEN <> ($this:<root>.Line_59_jupyter.drive.<no name provided>) returnType:kotlin.Any?
//               $this: VALUE_PARAMETER INSTANCE_RECEIVER name:<this> type:<root>.Line_59_jupyter.drive.<no name provided>
//               EXPRESSION_BODY
//                 RETURN type=kotlin.Nothing from='public open fun invoke (): kotlin.Any? declared in <root>.Line_59_jupyter.drive.<no name provided>'
//                   CALL 'public final fun invoke (): kotlin.Unit declared in <root>.Line_59_jupyter.drive.<no name provided>' type=kotlin.Unit origin=BRIDGE_DELEGATION
//                     $this: GET_VAR '<this>: <root>.Line_59_jupyter.drive.<no name provided> declared in <root>.Line_59_jupyter.drive.<no name provided>.invoke' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//           CONSTRUCTOR_CALL 'public constructor <init> ($nightCall: java.lang.Runnable) [primary] declared in <root>.Line_59_jupyter.drive.<no name provided>' type=<root>.Line_59_jupyter.drive.<no name provided> origin=null
//             $nightCall: GET_VAR 'val nightCall: java.lang.Runnable [val] declared in <root>.Line_59_jupyter.drive' type=java.lang.Runnable origin=null
//         $mask0: CONST Int type=kotlin.Int value=31
//         $handler: CONST Null type=kotlin.Any? value=null
//       COMPOSITE type=kotlin.Unit origin=null
//     CALL 'public abstract fun invoke (p1: P1 of kotlin.Function1): R of kotlin.Function1 [operator] declared in kotlin.Function1' type=kotlin.Unit origin=INVOKE
//       $this: GET_VAR 'call: kotlin.Function1<kotlin.String, kotlin.Unit> declared in <root>.Line_59_jupyter.drive' type=kotlin.Function1<kotlin.String, kotlin.Unit> origin=VARIABLE_AS_FUNCTION
//       p1: CONST String type=kotlin.String value="I'm gonna drive you through the night, down the hills"
//
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:51)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate$default(FunctionCodegen.kt:43)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.generateMethodNode(ClassCodegen.kt:396)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.IrSourceCompilerForInline.compileInlineFunction(IrSourceCompilerForInline.kt:93)
// 	at org.jetbrains.kotlin.codegen.inline.InlineCodegen.compileInline(InlineCodegen.kt:45)
// 	at org.jetbrains.kotlin.codegen.inline.InlineCodegen.performInline(InlineCodegen.kt:53)
// 	... 97 more
// Caused by: java.lang.IllegalStateException: Local class should have its name computed in InventNamesForLocalClasses: Line_59_jupyter.drive.<no name provided>
// Ensure that any lowering that transforms elements with local class info (classes, function references) invokes `copyAttributes` on the transformed element.
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMapper.computeClassInternalName(IrTypeMapper.kt:84)
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMapper.classInternalName(IrTypeMapper.kt:95)
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMapper.getClassInternalName(IrTypeMapper.kt:101)
// 	at org.jetbrains.kotlin.types.AbstractTypeMapper.mapClassType(AbstractTypeMapper.kt:190)
// 	at org.jetbrains.kotlin.types.AbstractTypeMapper.mapType(AbstractTypeMapper.kt:89)
// 	at org.jetbrains.kotlin.types.AbstractTypeMapper.mapType(AbstractTypeMapper.kt:53)
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMapper.mapType(IrTypeMapper.kt:134)
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMapper.mapType$default(IrTypeMapper.kt:129)
// 	at org.jetbrains.kotlin.backend.jvm.mapping.IrTypeMappingKt.mapClass(IrTypeMapping.kt:40)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.IrCodegenUtilsKt.getSourceMapper(irCodegenUtils.kt:74)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.<init>(ClassCodegen.kt:84)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen.<init>(ClassCodegen.kt)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen$Companion$getOrCreate$2.invoke(ClassCodegen.kt:552)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen$Companion$getOrCreate$2.invoke(ClassCodegen.kt:552)
// 	at org.jetbrains.kotlin.backend.jvm.JvmBackendContext.getOrCreateClassCodegen$lambda$0(JvmBackendContext.kt:147)
// 	at java.base/java.util.concurrent.ConcurrentHashMap.computeIfAbsent(ConcurrentHashMap.java:1708)
// 	at org.jetbrains.kotlin.backend.jvm.JvmBackendContext.getOrCreateClassCodegen(JvmBackendContext.kt:147)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ClassCodegen$Companion.getOrCreate(ClassCodegen.kt:552)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitClass(ExpressionCodegen.kt:966)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitClass(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.declarations.IrClass.accept(IrClass.kt:73)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitStatementContainer(ExpressionCodegen.kt:562)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:576)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitContainerExpression(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.visitors.IrElementVisitor$DefaultImpls.visitBlock(IrElementVisitor.kt:192)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:396)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlock(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrBlock.accept(IrBlock.kt:20)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitVariable(ExpressionCodegen.kt:757)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitVariable(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.declarations.IrVariable.accept(IrVariable.kt:38)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitStatementContainer(ExpressionCodegen.kt:562)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlockBody(ExpressionCodegen.kt:567)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.visitBlockBody(ExpressionCodegen.kt:134)
// 	at org.jetbrains.kotlin.ir.expressions.IrBlockBody.accept(IrBlockBody.kt:25)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.ExpressionCodegen.generate(ExpressionCodegen.kt:228)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.doGenerate(FunctionCodegen.kt:122)
// 	at org.jetbrains.kotlin.backend.jvm.codegen.FunctionCodegen.generate(FunctionCodegen.kt:47)
// 	... 102 more

// %% [markdown]
// ---
//
// # Inline reified functions
//
// <font size="5">Sometimes you need to access a type passed as a parameter:</font>

// %%
import org.jetbrains.kotlin.public.course.generics.Animal

fun <T: Animal> fooInlineError() {
    println(T::class) // ERROR: Cannot use 'T' as reified type parameter. Use a class instead---> add a param: t: KClass<T>
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[56], line 4, column 13: Cannot use 'T' as reified type parameter. Use a class instead.
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor$DefaultImpls.execute-L4Nmkdk$default(CellExecutor.kt:13)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:613)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:471)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.access$evalExImpl(ReplForJupyterImpl.kt:143)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:464)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl$evalEx$1.invoke(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withEvalContext(ReplForJupyterImpl.kt:444)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalEx(ReplForJupyterImpl.kt:463)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:159)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedIn(IdeCompatibleMessageRequestProcessor.kt:335)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedIn(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1$1.invoke(IdeCompatibleMessageRequestProcessor.kt:349)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedErr(IdeCompatibleMessageRequestProcessor.kt:324)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.access$withForkedErr(IdeCompatibleMessageRequestProcessor.kt:54)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$evalWithIO$1.invoke(IdeCompatibleMessageRequestProcessor.kt:348)
// 	at org.jetbrains.kotlinx.jupyter.streams.BlockingSubstitutionEngine.withDataSubstitution(SubstitutionEngine.kt:70)
// 	at org.jetbrains.kotlinx.jupyter.streams.StreamSubstitutionManager.withSubstitutedStreams(StreamSubstitutionManager.kt:118)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.withForkedOut(IdeCompatibleMessageRequestProcessor.kt:316)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor.evalWithIO(IdeCompatibleMessageRequestProcessor.kt:347)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:158)
// 	at org.jetbrains.kotlinx.jupyter.messaging.IdeCompatibleMessageRequestProcessor$processExecuteRequest$1$response$1.invoke(IdeCompatibleMessageRequestProcessor.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$Task.execute(JupyterExecutorImpl.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:83)
// 	at org.jetbrains.kotlinx.jupyter.execution.JupyterExecutorImpl$executorThread$1.invoke(JupyterExecutorImpl.kt:80)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)

// %% [markdown]
// <font size="5">You can use the `reified` keyword with `inline` functions:</font>

// %%
import org.jetbrains.kotlin.public.course.generics.Animal

inline fun <reified T: Animal> fooInlineOk() {
    println(T::class) // OK 
}

// %%
fooInlineOk<Animal>()
// Out:
// class org.jetbrains.kotlin.public.course.generics.Animal

// %% [markdown]
// <font size="5">Note that the compiler has to be able to know the actual type passed as a type argument so that it can modify the generated bytecode to use the corresponding class directly.</font>
