// %% [markdown]
// # Basics

// %%
2+2
// Out:
// 4

// %%
val result = 3*14

// %%
result
// Out:
// 42

// %%
%use dataframe

// %%
val aMSWeatherData = DataFrame.readCsv("AMS Weather Data.csv", delimiter = ',')
aMSWeatherData
// Out:
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
@file:DependsOn("org.mariadb.jdbc:mariadb-java-client:3.5.3")

// %%
import java.sql.DriverManager

val URL = "jdbc:mariadb://localhost:33066/imdb"
val USER_NAME = "root"
val PASSWORD = "mypass"

// %%
val connection       = DriverManager.getConnection(URL, USER_NAME, PASSWORD)
val prepareStatement = connection.prepareStatement("select * from actors")
val executeQuery     = prepareStatement.executeQuery()

// %%
val dfs = DataFrame.readSqlTable(connection, tableName = "actors", limit = 100)

// %%
dfs
// Out:
//             <iframe onload="o_resize_iframe_out_8()" style="width:100%;" class="result_container" id="iframe_out_8" frameBorder="0" srcdoc="        &lt;html&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
@file:DependsOn("io.github.serpro69:kotlin-faker:1.16.0")

// %%
import org.jetbrains.kotlinx.dataframe.api.*
import org.jetbrains.kotlinx.dataframe.*
import io.github.serpro69.kfaker.Faker
import java.sql.Date
import kotlin.random.Random
import java.time.LocalDate

val faker = Faker()
val numberOfActors = 50

// %%
val actors = List(numberOfActors) {
    val firstName = faker.name.firstName()
    val lastName = faker.name.lastName()

    mapOf(
        "actor_id" to it + 1,
        "first_name" to firstName,
        "last_name" to lastName,
    )
}

val actorsDataFrame = actors.toDataFrame()

// %%
actorsDataFrame
// Out:
//             <iframe onload="o_resize_iframe_out_10()" style="width:100%;" class="result_container" id="iframe_out_10" frameBorder="0" srcdoc="        &lt;html&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...
